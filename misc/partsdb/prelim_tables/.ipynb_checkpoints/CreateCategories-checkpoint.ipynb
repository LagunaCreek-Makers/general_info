# %%
from collections import OrderedDict

level0=None
level1=None
level2=None
level3=None

categories = OrderedDict()
cnt = 1
with open("Categories.txt",'rt') as fh:
    for ln in fh:
        ln = ln.rstrip()
        if ln == "":
            continue
        
        level = len(ln) - len(ln.lstrip("\t"))
            
        ln = ln.lstrip("\t")
        ln = ln.replace('\t', '/')
        
        if level == 4:
            
            if level3 is not None:
                parent = level3
            elif level2 is not None:
                parent = level2
            elif level1 is not None:
                parent = level1
            else:
                parent = level0
            
            
        elif level == 3:
            level3 = ln
            
            if level2 is not None:
                parent = level2
            elif level1 is not None:
                parent = level1
            else:
                parent = level0
        elif level ==2:
            level2 = ln
            level3 = None
            if level1 is not None:
                parent = level1
            else:
                parent = level0
        elif level ==1:
            level1 = ln
            level2 = None
            level3 = None
            parent = level0
        elif level == 0:
            level0 = ln 
            level1 = None
            level2 = None
            level3 = None
            parent = None
        
        if ln in categories:
            print(ln)
            continue
        
        
        categories[ln] = {'key':cnt, 'parent':parent, 'level':level}
        cnt+=1
# Out:
# Cable Carriers
# Stepper Motors
# Plastic Chains
# Rollers
# NAAMS Locating Pins
# NAAMS Pin Retainer
# NAAMS L-Block
# NAAMS NC Block
# NAAMS Rough Locators
# Rotary
# X-Axis
# XY-Axis
# Z-Axis
# Rotary
# Lens
# Sensors
# Proximity Sensors
# Proximity Sensors
# Switches
# Contact Switches
# Hands, Fingers for Grippers
# Filter
# Solenoid Valves
# Pneumatic Pipe Fittings
# Hands, Fingers for Grippers
# Vacuum Generators, Vacuum Ejectors
# Couplers, One-Touch Joints
# Valves
# Check Valves
# Resins, Ducts, Flexible Hoses
# Sanitary Pipes
# Strainers
# Nozzles
# Adjustable Hoses
# Open Tanks
# Temperature Controllers
# Sensor Peripheral Components
# Heat Sinks
# Pipe Frames
# Casters
# Casters
# Wheels
# Special Type
# Gas Springs
# Chains
# Accessories
# Hinges
# Shock Absorbers, Gas Springs
# Magnetic Bases
# Safety Protection Materials
# Plates
# Washers
# Washers
# Nuts
# Rivet
# Washers, Collars
# Metal Washers, Collars
# Non-Metal Washers, Collars
# Shims
# Shim Tapes
# Shim Plates
# Shim Rings
# Rectangular Shims
# Hair Pins, Cotter Pins
# Machine Keys
# Retaining Rings
# Screw Plugs
# Plates
# L-Brackets
# Round Plates
# Convex Bend Plates
# Z Plates
# Crimp terminal
# Zip tie
# Cable gland
# Screw/Spacer
# Cable accessories
# USB cable
# Display cable
# AV cable
# Printer cable
# PS/2 Standard cable
# SCSI Cable
# Antenna cable
# LAN Cable
# LAN Connector
# LAN Adapter
# Telephone line (RJ11)
# RS232C Cable
# Switches
# Stack Lights
# Display Lights
# Alarms/Buzzers
# Controllers
# Extension Boards
# Chassis
# PC Power Supplies
# HDD/SSD
# KVM/Display Extenders
# Circuit Protector
# Electromagnetic Switch
# AC Adapter
# Power Tap / Power Cord / Extension Cord (Options / Others)
# Extension Cords
# AC Receptacle / Inlets
# SPD Arrester (Lightning Arresters)
# Ferrite Core
# Data Converters
# LED lights
# Fan
# Slide Switches
# Display Lights
# Display Lights
# Carbide Ball End Mill
# Carbide Radius End Mill
# Safety Products
# Punches
# Pilot Punches
# Punch Guide Bushings
# Button Dies
# Block Punches
# Block Dies
# Carbide Punches
# Carbide Pilot Punches
# Carbide Button Dies
# Carbide Block Punches
# Carbide Block Dies
# Misfeed Sensor Units
# Retainers
# Guide Components
# Guide Posts
# Guide Bushings
# Stroke End Blocks
# Ball Guide Post Sets
# Spring Plungers
# Ball Plungers
# Dowel Pins
# Screw Plugs
# Magnets
# Washers
# Stroke End Blocks
# Stroke End Blocks
# Hinge Pins
# Tension Springs
# Nest Guides
# Locating Pins
# Material Guides
# Pushers
# Springs
# Round Wire Springs
# Coil Springs
# Gas Springs
# Gas Springs
# Urethane Springs
# Gas Release
# With Engraving
# No Tip Processing
# Gas Release
# Ejector Pins With Tip Process
# With Engraving
# Ejector Sleeves
# One-Step Center Pin Sets
# One-Step
# Two-Steps
# Ejector Pins With Tip Process
# Gas Release
# With Engraving
# One-Step
# Two-Steps
# Gas Release
# One-Step
# Two-Steps
# Gas Release
# Angled Pins
# Tension Links
# Cartridge Heaters
# Heating Items
# Thermometers
# O-Rings
# Coil Springs
# Spring Guide Pins
# Gas Springs
# Gas Springs
# Screw Plugs
# Dowel Pins
# Magnets

# %%
fh = open("CategoriesWithParent.txt",'wt')
for i in categories:
    if categories[i]['parent'] is not None:
        parent = categories[i]['parent']
        parent_key = categories[parent]['key']
        categories[i]['parent_key'] = parent_key
    else:
        categories[i]['parent_key'] = None
    
    print("{0}\t{1}\t{2}".format(categories[i]['key'], i, categories[i]['parent_key']), file=fh)
fh.close()

# %%
level0=None
level1=None
level2=None
level3=None

for i in categories:
    if 
    print(i)
    break
# Out:
# Integrated Circuits (ICs)

# %%
import mysql.connector
conn = mysql.connector.connect(user='django', password='sparhawk',
                              host='127.0.0.1',
                              database='partsdatabase')

conn.close()

# %%
data = list()
max_cat = 0
with open("CategoriesWithParent.txt",'rt') as fh:
    for ln in fh:
        line = ln.rstrip().split("\t")
        bn = int(line[0])
        category = line[1]
        if len(category) > max_cat:
            max_cat = len(category)
        
        parent_id = line[2] if line[2]!='None' else None
        data.append([bn,category,parent_id])

# %%
max_cat
# Out:
# 63

# %%
import mysql.connector
conn = mysql.connector.connect(user='django', password='sparhawk',
                              host='127.0.0.1',
                              database='partsdatabase')

command= "INSERT into `partsdatabase`.`category` (id,category,parent_id) VALUES (%s,%s,%s)"
curs = conn.cursor()
for entry in data:
    try:
        curs.execute(command,entry)
        conn.commit()
    except mysql.connector.Error as err:
        if err.errno == 1062:
            continue
        else:
            print(entry)

curs.close()
conn.close()

# %%
manufacturers = list()
max_man=0
cnt = 0
with open("Manufacturers.txt",'rt') as fh:
    for ln in fh:
        cnt+=1
        lst = ln.rstrip().split("\t")
        if len(lst[1]) > max_man:
            max_man = len(lst[1])
        manufacturers.append([cnt, lst[1], None])

# %%
import mysql.connector
conn = mysql.connector.connect(user='django', password='sparhawk',
                              host='127.0.0.1',
                              database='partsdatabase')

command= "INSERT into `partsdatabase`.`manufacturer` (id,manufacturer,homepage_url) VALUES (%s,%s,%s)"
curs = conn.cursor()
for entry in manufacturers:
    try:
        curs.execute(command,entry)
        conn.commit()
    except mysql.connector.Error as err:
        if err.errno == 1062:
            continue
        else:
            print(entry)

curs.close()
conn.close()

# %%
supplier = list()
max_supp = 0
cnt = 0
with open("Distributor.txt",'rt') as fh:
    for ln in fh:
        cnt+=1
        lst = ln.rstrip().split("\t")
        if len(lst[1]) > max_supp:
            max_supp = len(lst[1])
        supplier.append([cnt, lst[1], None])

# %%
max_supp
# Out:
# 36

# %%
import mysql.connector
conn = mysql.connector.connect(user='django', password='sparhawk',
                              host='127.0.0.1',
                              database='partsdatabase')

command= "INSERT into `partsdatabase`.`supplier` (id,name,url) VALUES (%s,%s,%s)"
curs = conn.cursor()
for entry in supplier:
    try:
        curs.execute(command,entry)
        conn.commit()
    except mysql.connector.Error as err:
        if err.errno == 1062:
            continue
        else:
            print(entry)

curs.close()
conn.close()
# Out:
# [1, '4 Star Electronics', None]
# [2, 'A.E. Petsche', None]
# [3, 'Abacus Technologies', None]
# [4, 'Ace Hardware', None]
# [5, 'Adafruit Industries', None]
# [6, 'All-Spec', None]
# [7, 'Allied Electronics', None]
# [8, 'Amarillo Electric', None]
# [9, 'Amphenol Cables on Demand', None]
# [10, 'Anixter', None]
# [11, 'Appliances Connection', None]
# [12, 'Approved Optics', None]
# [13, 'Arcadian', None]
# [14, 'Area51', None]
# [15, 'Area51-Authorized', None]
# [16, 'Arfine Electronics', None]
# [17, 'Armbar Industries', None]
# [18, 'Arrow', None]
# [19, 'Avnet', None]
# [20, 'Avnet Asia', None]
# [21, 'Avnet Europe', None]
# [22, 'AW Direct', None]
# [23, 'B+D Enterprises', None]
# [24, 'Ben-R-Tek', None]
# [25, 'Benchmark Connector Corporation', None]
# [26, 'Beyond Components', None]
# [27, 'Bisco', None]
# [28, 'Bravo Electro Components', None]
# [29, 'C Plus Electronics', None]
# [30, 'Calgreg', None]
# [31, 'CDM Electronics', None]
# [32, 'Chicago Electronic Distributors', None]
# [33, 'Chip 1 Exchange', None]
# [34, 'Chip One Stop Global', None]
# [35, 'Chip One Stop Japan', None]
# [36, 'Chip Outpost', None]
# [37, 'ChipNet', None]
# [38, 'Coast Pneumatics', None]
# [39, 'Coilcraft Direct', None]
# [40, 'Cole-Parmer', None]
# [41, 'Component Distributors Inc.', None]
# [42, 'Component Electronics', None]
# [43, 'Component Sense', None]
# [44, 'Conrad', None]
# [45, 'Control Design Supply', None]
# [46, 'Dachs', None]
# [47, 'DB Roberts', None]
# [48, 'DComponents', None]
# [49, 'Digi-Key', None]
# [50, 'Direct Components', None]
# [51, 'Distrelec', None]
# [52, 'Dove', None]
# [53, 'Edge Electronics', None]
# [54, 'Electro Enterprises', None]
# [55, 'Electro Sonic', None]
# [56, 'Electronic Connector Company', None]
# [57, 'Electronic Expediters', None]
# [58, 'Electronic Expeditors', None]
# [59, 'Electronic Supply', None]
# [60, 'ElectroShield', None]
# [61, 'element14 APAC', None]
# [62, 'Elmwood Electronics', None]
# [63, 'Elotronics', None]
# [64, 'eluomeng Electronics (China) Co. Ltd', None]
# [65, 'Epart123', None]
# [66, 'Euro-Tech', None]
# [67, 'Eurotronik', None]
# [68, 'ExcessParts.Net', None]
# [69, 'Farnell', None]
# [70, 'Florida Circuit', None]
# [71, 'Freedom EMG', None]
# [72, 'Freelance Electronics', None]
# [73, 'Future Electronics', None]
# [74, 'Galco', None]
# [75, 'Gemini Electronic Components', None]
# [76, "Gempler's", None]
# [77, 'Gerber', None]
# [78, 'Gopher Electronics', None]
# [79, 'GreenTree Electronics', None]
# [80, 'Halfin', None]
# [81, 'Hawk Electronics', None]
# [82, 'Heilind Electronics', None]
# [83, 'Heilind Electronics - Europe', None]
# [84, 'Hillas', None]
# [85, 'Hisco', None]
# [86, 'Hutch & Son', None]
# [87, 'IBS Electronics', None]
# [88, 'Integra Electronics', None]
# [89, 'Interstate Connecting Components', None]
# [90, 'iodParts', None]
# [91, 'Isotope Electronics', None]
# [92, 'Jameco', None]
# [93, 'Jet.com', None]
# [94, 'JieJie Electronics', None]
# [95, 'Kimco', None]
# [96, 'Kreger Components', None]
# [97, 'LCDPanels', None]
# [98, 'LCSC', None]
# [99, 'Livingston & Haven', None]
# [100, 'LTL Group', None]
# [101, 'Magellan Distribution', None]
# [102, 'Markertek', None]
# [103, 'Master Electronics', None]
# [104, 'materialboerse.de', None]
# [105, 'Medex Supply', None]
# [106, 'microchipDIRECT', None]
# [107, 'Midan Electronics', None]
# [108, 'Mixed Signal Integration', None]
# [109, 'Mouser', None]
# [110, 'MRO Stop', None]
# [111, 'MRO Supply', None]
# [112, 'MSC Industrial Supply', None]
# [113, 'NAC Semi', None]
# [114, 'NEP Electronics', None]
# [115, 'NetSource Technology', None]
# [116, 'New Yorker Electronics', None]
# [117, 'Newark', None]
# [118, 'Newegg', None]
# [119, 'Newegg Business', None]
# [120, 'Nexxon', None]
# [121, 'North Star Micro', None]
# [122, 'Octopart', None]
# [123, 'Omnical', None]
# [124, 'Onlinecomponents.com', None]
# [125, 'PCB Cart', None]
# [126, 'PCX', None]
# [127, 'Peak to Peak Power', None]
# [128, 'Peerless Electronic Supplies', None]
# [129, 'Peerless Electronics', None]
# [130, 'PEI Genesis', None]
# [131, 'PosiShop', None]
# [132, 'Powell Electronics', None]
# [133, 'Power and Signal Group', None]
# [134, 'PSC Electronics', None]
# [135, 'PUI', None]
# [136, 'PY Technology', None]
# [137, 'Quest', None]
# [138, 'Quist', None]
# [139, 'RACS', None]
# [140, "Ralph's Industrial Electronics", None]
# [141, 'Raptor Supplies', None]
# [142, 'Relay Specialties', None]
# [143, 'Resion', None]
# [144, 'Richardson RFPD', None]
# [145, 'Rochester Electronics', None]
# [146, 'Rotakorn', None]
# [147, 'RS Components', None]
# [148, 'Rutronik', None]
# [149, 'Sager Electronics', None]
# [150, 'Sager Power Systems', None]
# [151, 'Samtec', None]
# [152, 'Schukat', None]
# [153, 'Score Electronics', None]
# [154, 'Sears', None]
# [155, 'Select Technology', None]
# [156, 'SemiconductorPLUS', None]
# [157, 'ShopCross', None]
# [158, 'Shortec Electronics', None]
# [159, 'SIE Connect', None]
# [160, 'Simcona Electronics', None]
# [161, 'SOS electronic', None]
# [162, 'South Electronics', None]
# [163, 'SPEC', None]
# [164, 'Specialized Products', None]
# [165, 'Steven Engineering', None]
# [166, 'STLAA.com', None]
# [167, 'Summit Electronics', None]
# [168, 'Switches Unlimited', None]
# [169, 'Symmetry Electronics', None]
# [170, 'TE Connectivity LADD', None]
# [171, 'Telerex Europe', None]
# [172, 'Terminals & Connectors', None]
# [173, 'Test Equipment Depot', None]
# [174, 'Testco', None]
# [175, 'Texas Instruments', None]
# [176, 'TLC Electronics', None]
# [177, 'TME', None]
# [178, 'TodayComponents', None]
# [179, 'Touchstone Systems', None]
# [180, 'TRC Electronics', None]
# [181, 'TTI', None]
# [182, 'TTI Asia', None]
# [183, 'TTI Europe', None]
# [184, 'TTL Electronics', None]
# [185, 'USComponent', None]
# [186, 'Venkel', None]
# [187, 'Verical', None]
# [188, 'Voyager Components', None]
# [189, 'Walker Industrial', None]
# [190, 'Waytek', None]
# [191, 'WPG Americas', None]
# [192, 'Wuhan P&S', None]
# [193, 'York Supply', None]
# [194, 'Zoro', None]
